# %%
from torchvision import models
from torchvision.models import (
    ResNet18_Weights, 
    MobileNet_V3_Large_Weights, 
    EfficientNet_B2_Weights, 
    DenseNet121_Weights, 
    MNASNet1_3_Weights, 
    RegNet_X_1_6GF_Weights,
    RegNet_Y_3_2GF_Weights,
)
from torchinfo import summary

# %%
# get the model
model = models.regnet_y_3_2gf(weights=RegNet_Y_3_2GF_Weights.IMAGENET1K_V2)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# RegNet (RegNet)                                              [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─SimpleStemIN (stem)                                        [16, 3, 224, 224]    [16, 32, 112, 112]   --                   True
# │    └─Conv2d (0)                                            [16, 3, 224, 224]    [16, 32, 112, 112]   864                  True
# │    └─BatchNorm2d (1)                                       [16, 32, 112, 112]   [16, 32, 112, 112]   64                   True
# │    └─ReLU (2)                                              [16, 32, 112, 112]   [16, 32, 112, 112]   --                   --
# ├─Sequential (trunk_output)                                  [16, 32, 112, 112]   [16, 1512, 7, 7]     --                   True
# │    └─AnyStage (block1)                                     [16, 32, 112, 112]   [16, 72, 56, 56]     --                   True
# │    │    └─ResBottleneckBlock (block1-0)                    [16, 32, 112, 112]   [16, 72, 56, 56]     27,152               True
# │    │    └─ResBottleneckBlock (block1-1)                    [16, 72, 56, 56]     [16, 72, 56, 56]     29,034               True
# │    └─AnyStage (block2)                                     [16, 72, 56, 56]     [16, 216, 28, 28]    --                   True
# │    │    └─ResBottleneckBlock (block2-0)                    [16, 72, 56, 56]     [16, 216, 28, 28]    134,154              True
# │    │    └─ResBottleneckBlock (block2-1)                    [16, 216, 28, 28]    [16, 216, 28, 28]    164,862              True
# │    │    └─ResBottleneckBlock (block2-2)                    [16, 216, 28, 28]    [16, 216, 28, 28]    164,862              True
# │    │    └─ResBottleneckBlock (block2-3)                    [16, 216, 28, 28]    [16, 216, 28, 28]    164,862              True
# │    │    └─ResBottleneckBlock (block2-4)                    [16, 216, 28, 28]    [16, 216, 28, 28]    164,862              True
# │    └─AnyStage (block3)                                     [16, 216, 28, 28]    [16, 576, 14, 14]    --                   True
# │    │    └─ResBottleneckBlock (block3-0)                    [16, 216, 28, 28]    [16, 576, 14, 14]    772,470              True
# │    │    └─ResBottleneckBlock (block3-1)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-2)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-3)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-4)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-5)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-6)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-7)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-8)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-9)                    [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-10)                   [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-11)                   [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    │    └─ResBottleneckBlock (block3-12)                   [16, 576, 14, 14]    [16, 576, 14, 14]    958,032              True
# │    └─AnyStage (block4)                                     [16, 576, 14, 14]    [16, 1512, 7, 7]     --                   True
# │    │    └─ResBottleneckBlock (block4-0)                    [16, 576, 14, 14]    [16, 1512, 7, 7]     4,803,768            True
# ├─AdaptiveAvgPool2d (avgpool)                                [16, 1512, 7, 7]     [16, 1512, 1, 1]     --                   --
# ├─Linear (fc)                                                [16, 1512]           [16, 1000]           1,513,000            True
# ============================================================================================================================================
# Total params: 19,436,338
# Trainable params: 19,436,338
# Non-trainable params: 0
# Total mult-adds (G): 50.82
# ============================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2881.72
# Params size (MB): 77.75
# Estimated Total Size (MB): 2969.10
# ============================================================================================================================================

# %%
# get the model
model = models.regnet_x_1_6gf(weights=RegNet_X_1_6GF_Weights.IMAGENET1K_V1)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# ==================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ==================================================================================================================================
# RegNet (RegNet)                                    [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─SimpleStemIN (stem)                              [16, 3, 224, 224]    [16, 32, 112, 112]   --                   True
# │    └─Conv2d (0)                                  [16, 3, 224, 224]    [16, 32, 112, 112]   864                  True
# │    └─BatchNorm2d (1)                             [16, 32, 112, 112]   [16, 32, 112, 112]   64                   True
# │    └─ReLU (2)                                    [16, 32, 112, 112]   [16, 32, 112, 112]   --                   --
# ├─Sequential (trunk_output)                        [16, 32, 112, 112]   [16, 912, 7, 7]      --                   True
# │    └─AnyStage (block1)                           [16, 32, 112, 112]   [16, 72, 56, 56]     --                   True
# │    │    └─ResBottleneckBlock (block1-0)          [16, 32, 112, 112]   [16, 72, 56, 56]     25,920               True
# │    │    └─ResBottleneckBlock (block1-1)          [16, 72, 56, 56]     [16, 72, 56, 56]     26,352               True
# │    └─AnyStage (block2)                           [16, 72, 56, 56]     [16, 168, 28, 28]    --                   True
# │    │    └─ResBottleneckBlock (block2-0)          [16, 72, 56, 56]     [16, 168, 28, 28]    90,048               True
# │    │    └─ResBottleneckBlock (block2-1)          [16, 168, 28, 28]    [16, 168, 28, 28]    93,744               True
# │    │    └─ResBottleneckBlock (block2-2)          [16, 168, 28, 28]    [16, 168, 28, 28]    93,744               True
# │    │    └─ResBottleneckBlock (block2-3)          [16, 168, 28, 28]    [16, 168, 28, 28]    93,744               True
# │    └─AnyStage (block3)                           [16, 168, 28, 28]    [16, 408, 14, 14]    --                   True
# │    │    └─ResBottleneckBlock (block3-0)          [16, 168, 28, 28]    [16, 408, 14, 14]    394,944              True
# │    │    └─ResBottleneckBlock (block3-1)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-2)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-3)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-4)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-5)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-6)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-7)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-8)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    │    └─ResBottleneckBlock (block3-9)          [16, 408, 14, 14]    [16, 408, 14, 14]    423,504              True
# │    └─AnyStage (block4)                           [16, 408, 14, 14]    [16, 912, 7, 7]      --                   True
# │    │    └─ResBottleneckBlock (block4-0)          [16, 408, 14, 14]    [16, 912, 7, 7]      1,780,224            True
# │    │    └─ResBottleneckBlock (block4-1)          [16, 912, 7, 7]      [16, 912, 7, 7]      1,865,952            True
# ├─AdaptiveAvgPool2d (avgpool)                      [16, 912, 7, 7]      [16, 912, 1, 1]      --                   --
# ├─Linear (fc)                                      [16, 912]            [16, 1000]           913,000              True
# ==================================================================================================================================
# Total params: 9,190,136
# Trainable params: 9,190,136
# Non-trainable params: 0
# Total mult-adds (G): 25.65
# ==================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2030.85
# Params size (MB): 36.76
# Estimated Total Size (MB): 2077.25
# ==================================================================================================================================

# %%
# get the model
model = models.mnasnet1_3(weights=MNASNet1_3_Weights.IMAGENET1K_V1)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# MNASNet (MNASNet)                             [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Sequential (layers)                         [16, 3, 224, 224]    [16, 1280, 7, 7]     --                   True
# │    └─Conv2d (0)                             [16, 3, 224, 224]    [16, 40, 112, 112]   1,080                True
# │    └─BatchNorm2d (1)                        [16, 40, 112, 112]   [16, 40, 112, 112]   80                   True
# │    └─ReLU (2)                               [16, 40, 112, 112]   [16, 40, 112, 112]   --                   --
# │    └─Conv2d (3)                             [16, 40, 112, 112]   [16, 40, 112, 112]   360                  True
# │    └─BatchNorm2d (4)                        [16, 40, 112, 112]   [16, 40, 112, 112]   80                   True
# │    └─ReLU (5)                               [16, 40, 112, 112]   [16, 40, 112, 112]   --                   --
# │    └─Conv2d (6)                             [16, 40, 112, 112]   [16, 24, 112, 112]   960                  True
# │    └─BatchNorm2d (7)                        [16, 24, 112, 112]   [16, 24, 112, 112]   48                   True
# │    └─Sequential (8)                         [16, 24, 112, 112]   [16, 32, 56, 56]     --                   True
# │    │    └─_InvertedResidual (0)             [16, 24, 112, 112]   [16, 32, 56, 56]     5,032                True
# │    │    └─_InvertedResidual (1)             [16, 32, 56, 56]     [16, 32, 56, 56]     7,456                True
# │    │    └─_InvertedResidual (2)             [16, 32, 56, 56]     [16, 32, 56, 56]     7,456                True
# │    └─Sequential (9)                         [16, 32, 56, 56]     [16, 56, 28, 28]     --                   True
# │    │    └─_InvertedResidual (0)             [16, 32, 56, 56]     [16, 56, 28, 28]     11,344               True
# │    │    └─_InvertedResidual (1)             [16, 56, 28, 28]     [16, 56, 28, 28]     23,800               True
# │    │    └─_InvertedResidual (2)             [16, 56, 28, 28]     [16, 56, 28, 28]     23,800               True
# │    └─Sequential (10)                        [16, 56, 28, 28]     [16, 104, 14, 14]    --                   True
# │    │    └─_InvertedResidual (0)             [16, 56, 28, 28]     [16, 104, 14, 14]    63,712               True
# │    │    └─_InvertedResidual (1)             [16, 104, 14, 14]    [16, 104, 14, 14]    148,096              True
# │    │    └─_InvertedResidual (2)             [16, 104, 14, 14]    [16, 104, 14, 14]    148,096              True
# │    └─Sequential (11)                        [16, 104, 14, 14]    [16, 128, 14, 14]    --                   True
# │    │    └─_InvertedResidual (0)             [16, 104, 14, 14]    [16, 128, 14, 14]    153,136              True
# │    │    └─_InvertedResidual (1)             [16, 128, 14, 14]    [16, 128, 14, 14]    206,848              True
# │    └─Sequential (12)                        [16, 128, 14, 14]    [16, 248, 7, 7]      --                   True
# │    │    └─_InvertedResidual (0)             [16, 128, 14, 14]    [16, 248, 7, 7]      311,536              True
# │    │    └─_InvertedResidual (1)             [16, 248, 7, 7]      [16, 248, 7, 7]      781,696              True
# │    │    └─_InvertedResidual (2)             [16, 248, 7, 7]      [16, 248, 7, 7]      781,696              True
# │    │    └─_InvertedResidual (3)             [16, 248, 7, 7]      [16, 248, 7, 7]      781,696              True
# │    └─Sequential (13)                        [16, 248, 7, 7]      [16, 416, 7, 7]      --                   True
# │    │    └─_InvertedResidual (0)             [16, 248, 7, 7]      [16, 416, 7, 7]      1,008,208            True
# │    └─Conv2d (14)                            [16, 416, 7, 7]      [16, 1280, 7, 7]     532,480              True
# │    └─BatchNorm2d (15)                       [16, 1280, 7, 7]     [16, 1280, 7, 7]     2,560                True
# │    └─ReLU (16)                              [16, 1280, 7, 7]     [16, 1280, 7, 7]     --                   --
# ├─Sequential (classifier)                     [16, 1280]           [16, 1000]           --                   True
# │    └─Dropout (0)                            [16, 1280]           [16, 1280]           --                   --
# │    └─Linear (1)                             [16, 1280]           [16, 1000]           1,281,000            True
# =============================================================================================================================
# Total params: 6,282,256
# Trainable params: 6,282,256
# Non-trainable params: 0
# Total mult-adds (G): 8.42
# =============================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 1882.33
# Params size (MB): 25.13
# Estimated Total Size (MB): 1917.09
# =============================================================================================================================

# %%
# get the model
model = models.densenet121(weights=DenseNet121_Weights.IMAGENET1K_V1)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# =============================================================================================================================
# Layer (type (var_name))                       Input Shape          Output Shape         Param #              Trainable
# =============================================================================================================================
# DenseNet (DenseNet)                           [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Sequential (features)                       [16, 3, 224, 224]    [16, 1024, 7, 7]     --                   True
# │    └─Conv2d (conv0)                         [16, 3, 224, 224]    [16, 64, 112, 112]   9,408                True
# │    └─BatchNorm2d (norm0)                    [16, 64, 112, 112]   [16, 64, 112, 112]   128                  True
# │    └─ReLU (relu0)                           [16, 64, 112, 112]   [16, 64, 112, 112]   --                   --
# │    └─MaxPool2d (pool0)                      [16, 64, 112, 112]   [16, 64, 56, 56]     --                   --
# │    └─_DenseBlock (denseblock1)              [16, 64, 56, 56]     [16, 256, 56, 56]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 64, 56, 56]     [16, 32, 56, 56]     45,440               True
# │    │    └─_DenseLayer (denselayer2)         [16, 64, 56, 56]     [16, 32, 56, 56]     49,600               True
# │    │    └─_DenseLayer (denselayer3)         [16, 64, 56, 56]     [16, 32, 56, 56]     53,760               True
# │    │    └─_DenseLayer (denselayer4)         [16, 64, 56, 56]     [16, 32, 56, 56]     57,920               True
# │    │    └─_DenseLayer (denselayer5)         [16, 64, 56, 56]     [16, 32, 56, 56]     62,080               True
# │    │    └─_DenseLayer (denselayer6)         [16, 64, 56, 56]     [16, 32, 56, 56]     66,240               True
# │    └─_Transition (transition1)              [16, 256, 56, 56]    [16, 128, 28, 28]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 256, 56, 56]    [16, 256, 56, 56]    512                  True
# │    │    └─ReLU (relu)                       [16, 256, 56, 56]    [16, 256, 56, 56]    --                   --
# │    │    └─Conv2d (conv)                     [16, 256, 56, 56]    [16, 128, 56, 56]    32,768               True
# │    │    └─AvgPool2d (pool)                  [16, 128, 56, 56]    [16, 128, 28, 28]    --                   --
# │    └─_DenseBlock (denseblock2)              [16, 128, 28, 28]    [16, 512, 28, 28]    --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 128, 28, 28]    [16, 32, 28, 28]     53,760               True
# │    │    └─_DenseLayer (denselayer2)         [16, 128, 28, 28]    [16, 32, 28, 28]     57,920               True
# │    │    └─_DenseLayer (denselayer3)         [16, 128, 28, 28]    [16, 32, 28, 28]     62,080               True
# │    │    └─_DenseLayer (denselayer4)         [16, 128, 28, 28]    [16, 32, 28, 28]     66,240               True
# │    │    └─_DenseLayer (denselayer5)         [16, 128, 28, 28]    [16, 32, 28, 28]     70,400               True
# │    │    └─_DenseLayer (denselayer6)         [16, 128, 28, 28]    [16, 32, 28, 28]     74,560               True
# │    │    └─_DenseLayer (denselayer7)         [16, 128, 28, 28]    [16, 32, 28, 28]     78,720               True
# │    │    └─_DenseLayer (denselayer8)         [16, 128, 28, 28]    [16, 32, 28, 28]     82,880               True
# │    │    └─_DenseLayer (denselayer9)         [16, 128, 28, 28]    [16, 32, 28, 28]     87,040               True
# │    │    └─_DenseLayer (denselayer10)        [16, 128, 28, 28]    [16, 32, 28, 28]     91,200               True
# │    │    └─_DenseLayer (denselayer11)        [16, 128, 28, 28]    [16, 32, 28, 28]     95,360               True
# │    │    └─_DenseLayer (denselayer12)        [16, 128, 28, 28]    [16, 32, 28, 28]     99,520               True
# │    └─_Transition (transition2)              [16, 512, 28, 28]    [16, 256, 14, 14]    --                   True
# │    │    └─BatchNorm2d (norm)                [16, 512, 28, 28]    [16, 512, 28, 28]    1,024                True
# │    │    └─ReLU (relu)                       [16, 512, 28, 28]    [16, 512, 28, 28]    --                   --
# │    │    └─Conv2d (conv)                     [16, 512, 28, 28]    [16, 256, 28, 28]    131,072              True
# │    │    └─AvgPool2d (pool)                  [16, 256, 28, 28]    [16, 256, 14, 14]    --                   --
# │    └─_DenseBlock (denseblock3)              [16, 256, 14, 14]    [16, 1024, 14, 14]   --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 256, 14, 14]    [16, 32, 14, 14]     70,400               True
# │    │    └─_DenseLayer (denselayer2)         [16, 256, 14, 14]    [16, 32, 14, 14]     74,560               True
# │    │    └─_DenseLayer (denselayer3)         [16, 256, 14, 14]    [16, 32, 14, 14]     78,720               True
# │    │    └─_DenseLayer (denselayer4)         [16, 256, 14, 14]    [16, 32, 14, 14]     82,880               True
# │    │    └─_DenseLayer (denselayer5)         [16, 256, 14, 14]    [16, 32, 14, 14]     87,040               True
# │    │    └─_DenseLayer (denselayer6)         [16, 256, 14, 14]    [16, 32, 14, 14]     91,200               True
# │    │    └─_DenseLayer (denselayer7)         [16, 256, 14, 14]    [16, 32, 14, 14]     95,360               True
# │    │    └─_DenseLayer (denselayer8)         [16, 256, 14, 14]    [16, 32, 14, 14]     99,520               True
# │    │    └─_DenseLayer (denselayer9)         [16, 256, 14, 14]    [16, 32, 14, 14]     103,680              True
# │    │    └─_DenseLayer (denselayer10)        [16, 256, 14, 14]    [16, 32, 14, 14]     107,840              True
# │    │    └─_DenseLayer (denselayer11)        [16, 256, 14, 14]    [16, 32, 14, 14]     112,000              True
# │    │    └─_DenseLayer (denselayer12)        [16, 256, 14, 14]    [16, 32, 14, 14]     116,160              True
# │    │    └─_DenseLayer (denselayer13)        [16, 256, 14, 14]    [16, 32, 14, 14]     120,320              True
# │    │    └─_DenseLayer (denselayer14)        [16, 256, 14, 14]    [16, 32, 14, 14]     124,480              True
# │    │    └─_DenseLayer (denselayer15)        [16, 256, 14, 14]    [16, 32, 14, 14]     128,640              True
# │    │    └─_DenseLayer (denselayer16)        [16, 256, 14, 14]    [16, 32, 14, 14]     132,800              True
# │    │    └─_DenseLayer (denselayer17)        [16, 256, 14, 14]    [16, 32, 14, 14]     136,960              True
# │    │    └─_DenseLayer (denselayer18)        [16, 256, 14, 14]    [16, 32, 14, 14]     141,120              True
# │    │    └─_DenseLayer (denselayer19)        [16, 256, 14, 14]    [16, 32, 14, 14]     145,280              True
# │    │    └─_DenseLayer (denselayer20)        [16, 256, 14, 14]    [16, 32, 14, 14]     149,440              True
# │    │    └─_DenseLayer (denselayer21)        [16, 256, 14, 14]    [16, 32, 14, 14]     153,600              True
# │    │    └─_DenseLayer (denselayer22)        [16, 256, 14, 14]    [16, 32, 14, 14]     157,760              True
# │    │    └─_DenseLayer (denselayer23)        [16, 256, 14, 14]    [16, 32, 14, 14]     161,920              True
# │    │    └─_DenseLayer (denselayer24)        [16, 256, 14, 14]    [16, 32, 14, 14]     166,080              True
# │    └─_Transition (transition3)              [16, 1024, 14, 14]   [16, 512, 7, 7]      --                   True
# │    │    └─BatchNorm2d (norm)                [16, 1024, 14, 14]   [16, 1024, 14, 14]   2,048                True
# │    │    └─ReLU (relu)                       [16, 1024, 14, 14]   [16, 1024, 14, 14]   --                   --
# │    │    └─Conv2d (conv)                     [16, 1024, 14, 14]   [16, 512, 14, 14]    524,288              True
# │    │    └─AvgPool2d (pool)                  [16, 512, 14, 14]    [16, 512, 7, 7]      --                   --
# │    └─_DenseBlock (denseblock4)              [16, 512, 7, 7]      [16, 1024, 7, 7]     --                   True
# │    │    └─_DenseLayer (denselayer1)         [16, 512, 7, 7]      [16, 32, 7, 7]       103,680              True
# │    │    └─_DenseLayer (denselayer2)         [16, 512, 7, 7]      [16, 32, 7, 7]       107,840              True
# │    │    └─_DenseLayer (denselayer3)         [16, 512, 7, 7]      [16, 32, 7, 7]       112,000              True
# │    │    └─_DenseLayer (denselayer4)         [16, 512, 7, 7]      [16, 32, 7, 7]       116,160              True
# │    │    └─_DenseLayer (denselayer5)         [16, 512, 7, 7]      [16, 32, 7, 7]       120,320              True
# │    │    └─_DenseLayer (denselayer6)         [16, 512, 7, 7]      [16, 32, 7, 7]       124,480              True
# │    │    └─_DenseLayer (denselayer7)         [16, 512, 7, 7]      [16, 32, 7, 7]       128,640              True
# │    │    └─_DenseLayer (denselayer8)         [16, 512, 7, 7]      [16, 32, 7, 7]       132,800              True
# │    │    └─_DenseLayer (denselayer9)         [16, 512, 7, 7]      [16, 32, 7, 7]       136,960              True
# │    │    └─_DenseLayer (denselayer10)        [16, 512, 7, 7]      [16, 32, 7, 7]       141,120              True
# │    │    └─_DenseLayer (denselayer11)        [16, 512, 7, 7]      [16, 32, 7, 7]       145,280              True
# │    │    └─_DenseLayer (denselayer12)        [16, 512, 7, 7]      [16, 32, 7, 7]       149,440              True
# │    │    └─_DenseLayer (denselayer13)        [16, 512, 7, 7]      [16, 32, 7, 7]       153,600              True
# │    │    └─_DenseLayer (denselayer14)        [16, 512, 7, 7]      [16, 32, 7, 7]       157,760              True
# │    │    └─_DenseLayer (denselayer15)        [16, 512, 7, 7]      [16, 32, 7, 7]       161,920              True
# │    │    └─_DenseLayer (denselayer16)        [16, 512, 7, 7]      [16, 32, 7, 7]       166,080              True
# │    └─BatchNorm2d (norm5)                    [16, 1024, 7, 7]     [16, 1024, 7, 7]     2,048                True
# ├─Linear (classifier)                         [16, 1024]           [16, 1000]           1,025,000            True
# =============================================================================================================================
# Total params: 7,978,856
# Trainable params: 7,978,856
# Non-trainable params: 0
# Total mult-adds (G): 45.35
# =============================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2888.66
# Params size (MB): 31.92
# Estimated Total Size (MB): 2930.21
# =============================================================================================================================

# %%
# get the model
model = models.efficientnet_b2(weights=EfficientNet_B2_Weights.IMAGENET1K_V1)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# EfficientNet (EfficientNet)                                  [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Sequential (features)                                      [16, 3, 224, 224]    [16, 1408, 7, 7]     --                   True
# │    └─Conv2dNormActivation (0)                              [16, 3, 224, 224]    [16, 32, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [16, 3, 224, 224]    [16, 32, 112, 112]   864                  True
# │    │    └─BatchNorm2d (1)                                  [16, 32, 112, 112]   [16, 32, 112, 112]   64                   True
# │    │    └─SiLU (2)                                         [16, 32, 112, 112]   [16, 32, 112, 112]   --                   --
# │    └─Sequential (1)                                        [16, 32, 112, 112]   [16, 16, 112, 112]   --                   True
# │    │    └─MBConv (0)                                       [16, 32, 112, 112]   [16, 16, 112, 112]   1,448                True
# │    │    └─MBConv (1)                                       [16, 16, 112, 112]   [16, 16, 112, 112]   612                  True
# │    └─Sequential (2)                                        [16, 16, 112, 112]   [16, 24, 56, 56]     --                   True
# │    │    └─MBConv (0)                                       [16, 16, 112, 112]   [16, 24, 56, 56]     6,004                True
# │    │    └─MBConv (1)                                       [16, 24, 56, 56]     [16, 24, 56, 56]     10,710               True
# │    │    └─MBConv (2)                                       [16, 24, 56, 56]     [16, 24, 56, 56]     10,710               True
# │    └─Sequential (3)                                        [16, 24, 56, 56]     [16, 48, 28, 28]     --                   True
# │    │    └─MBConv (0)                                       [16, 24, 56, 56]     [16, 48, 28, 28]     16,518               True
# │    │    └─MBConv (1)                                       [16, 48, 28, 28]     [16, 48, 28, 28]     43,308               True
# │    │    └─MBConv (2)                                       [16, 48, 28, 28]     [16, 48, 28, 28]     43,308               True
# │    └─Sequential (4)                                        [16, 48, 28, 28]     [16, 88, 14, 14]     --                   True
# │    │    └─MBConv (0)                                       [16, 48, 28, 28]     [16, 88, 14, 14]     50,300               True
# │    │    └─MBConv (1)                                       [16, 88, 14, 14]     [16, 88, 14, 14]     123,750              True
# │    │    └─MBConv (2)                                       [16, 88, 14, 14]     [16, 88, 14, 14]     123,750              True
# │    │    └─MBConv (3)                                       [16, 88, 14, 14]     [16, 88, 14, 14]     123,750              True
# │    └─Sequential (5)                                        [16, 88, 14, 14]     [16, 120, 14, 14]    --                   True
# │    │    └─MBConv (0)                                       [16, 88, 14, 14]     [16, 120, 14, 14]    149,158              True
# │    │    └─MBConv (1)                                       [16, 120, 14, 14]    [16, 120, 14, 14]    237,870              True
# │    │    └─MBConv (2)                                       [16, 120, 14, 14]    [16, 120, 14, 14]    237,870              True
# │    │    └─MBConv (3)                                       [16, 120, 14, 14]    [16, 120, 14, 14]    237,870              True
# │    └─Sequential (6)                                        [16, 120, 14, 14]    [16, 208, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [16, 120, 14, 14]    [16, 208, 7, 7]      301,406              True
# │    │    └─MBConv (1)                                       [16, 208, 7, 7]      [16, 208, 7, 7]      686,868              True
# │    │    └─MBConv (2)                                       [16, 208, 7, 7]      [16, 208, 7, 7]      686,868              True
# │    │    └─MBConv (3)                                       [16, 208, 7, 7]      [16, 208, 7, 7]      686,868              True
# │    │    └─MBConv (4)                                       [16, 208, 7, 7]      [16, 208, 7, 7]      686,868              True
# │    └─Sequential (7)                                        [16, 208, 7, 7]      [16, 352, 7, 7]      --                   True
# │    │    └─MBConv (0)                                       [16, 208, 7, 7]      [16, 352, 7, 7]      846,900              True
# │    │    └─MBConv (1)                                       [16, 352, 7, 7]      [16, 352, 7, 7]      1,888,920            True
# │    └─Conv2dNormActivation (8)                              [16, 352, 7, 7]      [16, 1408, 7, 7]     --                   True
# │    │    └─Conv2d (0)                                       [16, 352, 7, 7]      [16, 1408, 7, 7]     495,616              True
# │    │    └─BatchNorm2d (1)                                  [16, 1408, 7, 7]     [16, 1408, 7, 7]     2,816                True
# │    │    └─SiLU (2)                                         [16, 1408, 7, 7]     [16, 1408, 7, 7]     --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [16, 1408, 7, 7]     [16, 1408, 1, 1]     --                   --
# ├─Sequential (classifier)                                    [16, 1408]           [16, 1000]           --                   True
# │    └─Dropout (0)                                           [16, 1408]           [16, 1408]           --                   --
# │    └─Linear (1)                                            [16, 1408]           [16, 1000]           1,409,000            True
# ============================================================================================================================================
# Total params: 9,109,994
# Trainable params: 9,109,994
# Non-trainable params: 0
# Total mult-adds (G): 10.54
# ============================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 2508.89
# Params size (MB): 36.44
# Estimated Total Size (MB): 2554.97
# ============================================================================================================================================

# %%
# get the model
model = models.mobilenet_v3_large(weights=MobileNet_V3_Large_Weights.IMAGENET1K_V2)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# ============================================================================================================================================
# Layer (type (var_name))                                      Input Shape          Output Shape         Param #              Trainable
# ============================================================================================================================================
# MobileNetV3 (MobileNetV3)                                    [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Sequential (features)                                      [16, 3, 224, 224]    [16, 960, 7, 7]      --                   True
# │    └─Conv2dNormActivation (0)                              [16, 3, 224, 224]    [16, 16, 112, 112]   --                   True
# │    │    └─Conv2d (0)                                       [16, 3, 224, 224]    [16, 16, 112, 112]   432                  True
# │    │    └─BatchNorm2d (1)                                  [16, 16, 112, 112]   [16, 16, 112, 112]   32                   True
# │    │    └─Hardswish (2)                                    [16, 16, 112, 112]   [16, 16, 112, 112]   --                   --
# │    └─InvertedResidual (1)                                  [16, 16, 112, 112]   [16, 16, 112, 112]   --                   True
# │    │    └─Sequential (block)                               [16, 16, 112, 112]   [16, 16, 112, 112]   464                  True
# │    └─InvertedResidual (2)                                  [16, 16, 112, 112]   [16, 24, 56, 56]     --                   True
# │    │    └─Sequential (block)                               [16, 16, 112, 112]   [16, 24, 56, 56]     3,440                True
# │    └─InvertedResidual (3)                                  [16, 24, 56, 56]     [16, 24, 56, 56]     --                   True
# │    │    └─Sequential (block)                               [16, 24, 56, 56]     [16, 24, 56, 56]     4,440                True
# │    └─InvertedResidual (4)                                  [16, 24, 56, 56]     [16, 40, 28, 28]     --                   True
# │    │    └─Sequential (block)                               [16, 24, 56, 56]     [16, 40, 28, 28]     10,328               True
# │    └─InvertedResidual (5)                                  [16, 40, 28, 28]     [16, 40, 28, 28]     --                   True
# │    │    └─Sequential (block)                               [16, 40, 28, 28]     [16, 40, 28, 28]     20,992               True
# │    └─InvertedResidual (6)                                  [16, 40, 28, 28]     [16, 40, 28, 28]     --                   True
# │    │    └─Sequential (block)                               [16, 40, 28, 28]     [16, 40, 28, 28]     20,992               True
# │    └─InvertedResidual (7)                                  [16, 40, 28, 28]     [16, 80, 14, 14]     --                   True
# │    │    └─Sequential (block)                               [16, 40, 28, 28]     [16, 80, 14, 14]     32,080               True
# │    └─InvertedResidual (8)                                  [16, 80, 14, 14]     [16, 80, 14, 14]     --                   True
# │    │    └─Sequential (block)                               [16, 80, 14, 14]     [16, 80, 14, 14]     34,760               True
# │    └─InvertedResidual (9)                                  [16, 80, 14, 14]     [16, 80, 14, 14]     --                   True
# │    │    └─Sequential (block)                               [16, 80, 14, 14]     [16, 80, 14, 14]     31,992               True
# │    └─InvertedResidual (10)                                 [16, 80, 14, 14]     [16, 80, 14, 14]     --                   True
# │    │    └─Sequential (block)                               [16, 80, 14, 14]     [16, 80, 14, 14]     31,992               True
# │    └─InvertedResidual (11)                                 [16, 80, 14, 14]     [16, 112, 14, 14]    --                   True
# │    │    └─Sequential (block)                               [16, 80, 14, 14]     [16, 112, 14, 14]    214,424              True
# │    └─InvertedResidual (12)                                 [16, 112, 14, 14]    [16, 112, 14, 14]    --                   True
# │    │    └─Sequential (block)                               [16, 112, 14, 14]    [16, 112, 14, 14]    386,120              True
# │    └─InvertedResidual (13)                                 [16, 112, 14, 14]    [16, 160, 7, 7]      --                   True
# │    │    └─Sequential (block)                               [16, 112, 14, 14]    [16, 160, 7, 7]      429,224              True
# │    └─InvertedResidual (14)                                 [16, 160, 7, 7]      [16, 160, 7, 7]      --                   True
# │    │    └─Sequential (block)                               [16, 160, 7, 7]      [16, 160, 7, 7]      797,360              True
# │    └─InvertedResidual (15)                                 [16, 160, 7, 7]      [16, 160, 7, 7]      --                   True
# │    │    └─Sequential (block)                               [16, 160, 7, 7]      [16, 160, 7, 7]      797,360              True
# │    └─Conv2dNormActivation (16)                             [16, 160, 7, 7]      [16, 960, 7, 7]      --                   True
# │    │    └─Conv2d (0)                                       [16, 160, 7, 7]      [16, 960, 7, 7]      153,600              True
# │    │    └─BatchNorm2d (1)                                  [16, 960, 7, 7]      [16, 960, 7, 7]      1,920                True
# │    │    └─Hardswish (2)                                    [16, 960, 7, 7]      [16, 960, 7, 7]      --                   --
# ├─AdaptiveAvgPool2d (avgpool)                                [16, 960, 7, 7]      [16, 960, 1, 1]      --                   --
# ├─Sequential (classifier)                                    [16, 960]            [16, 1000]           --                   True
# │    └─Linear (0)                                            [16, 960]            [16, 1280]           1,230,080            True
# │    └─Hardswish (1)                                         [16, 1280]           [16, 1280]           --                   --
# │    └─Dropout (2)                                           [16, 1280]           [16, 1280]           --                   --
# │    └─Linear (3)                                            [16, 1280]           [16, 1000]           1,281,000            True
# ============================================================================================================================================
# Total params: 5,483,032
# Trainable params: 5,483,032
# Non-trainable params: 0
# Total mult-adds (G): 3.47
# ============================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 1127.29
# Params size (MB): 21.93
# Estimated Total Size (MB): 1158.86
# ============================================================================================================================================

# %%
# get the model
model = models.resnet18(weights=ResNet18_Weights.DEFAULT)

batch_size = 16
channels = 3
img_width = 224
img_height = 224

# Print a summary using torchinfo (uncomment for actual output)
summary(model=model, 
	input_size=(batch_size, channels, img_width, img_height), # make sure this is "input_size", not "input_shape"
	# col_names=["input_size"], # uncomment for smaller output
	col_names=["input_size", "output_size", "num_params", "trainable"],
	col_width=20,
	row_settings=["var_names"]
)
# Out:
# ========================================================================================================================
# Layer (type (var_name))                  Input Shape          Output Shape         Param #              Trainable
# ========================================================================================================================
# ResNet (ResNet)                          [16, 3, 224, 224]    [16, 1000]           --                   True
# ├─Conv2d (conv1)                         [16, 3, 224, 224]    [16, 64, 112, 112]   9,408                True
# ├─BatchNorm2d (bn1)                      [16, 64, 112, 112]   [16, 64, 112, 112]   128                  True
# ├─ReLU (relu)                            [16, 64, 112, 112]   [16, 64, 112, 112]   --                   --
# ├─MaxPool2d (maxpool)                    [16, 64, 112, 112]   [16, 64, 56, 56]     --                   --
# ├─Sequential (layer1)                    [16, 64, 56, 56]     [16, 64, 56, 56]     --                   True
# │    └─BasicBlock (0)                    [16, 64, 56, 56]     [16, 64, 56, 56]     --                   True
# │    │    └─Conv2d (conv1)               [16, 64, 56, 56]     [16, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn1)            [16, 64, 56, 56]     [16, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [16, 64, 56, 56]     [16, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [16, 64, 56, 56]     [16, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn2)            [16, 64, 56, 56]     [16, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [16, 64, 56, 56]     [16, 64, 56, 56]     --                   --
# │    └─BasicBlock (1)                    [16, 64, 56, 56]     [16, 64, 56, 56]     --                   True
# │    │    └─Conv2d (conv1)               [16, 64, 56, 56]     [16, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn1)            [16, 64, 56, 56]     [16, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [16, 64, 56, 56]     [16, 64, 56, 56]     --                   --
# │    │    └─Conv2d (conv2)               [16, 64, 56, 56]     [16, 64, 56, 56]     36,864               True
# │    │    └─BatchNorm2d (bn2)            [16, 64, 56, 56]     [16, 64, 56, 56]     128                  True
# │    │    └─ReLU (relu)                  [16, 64, 56, 56]     [16, 64, 56, 56]     --                   --
# ├─Sequential (layer2)                    [16, 64, 56, 56]     [16, 128, 28, 28]    --                   True
# │    └─BasicBlock (0)                    [16, 64, 56, 56]     [16, 128, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [16, 64, 56, 56]     [16, 128, 28, 28]    73,728               True
# │    │    └─BatchNorm2d (bn1)            [16, 128, 28, 28]    [16, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [16, 128, 28, 28]    [16, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [16, 128, 28, 28]    [16, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [16, 128, 28, 28]    [16, 128, 28, 28]    256                  True
# │    │    └─Sequential (downsample)      [16, 64, 56, 56]     [16, 128, 28, 28]    8,448                True
# │    │    └─ReLU (relu)                  [16, 128, 28, 28]    [16, 128, 28, 28]    --                   --
# │    └─BasicBlock (1)                    [16, 128, 28, 28]    [16, 128, 28, 28]    --                   True
# │    │    └─Conv2d (conv1)               [16, 128, 28, 28]    [16, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn1)            [16, 128, 28, 28]    [16, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [16, 128, 28, 28]    [16, 128, 28, 28]    --                   --
# │    │    └─Conv2d (conv2)               [16, 128, 28, 28]    [16, 128, 28, 28]    147,456              True
# │    │    └─BatchNorm2d (bn2)            [16, 128, 28, 28]    [16, 128, 28, 28]    256                  True
# │    │    └─ReLU (relu)                  [16, 128, 28, 28]    [16, 128, 28, 28]    --                   --
# ├─Sequential (layer3)                    [16, 128, 28, 28]    [16, 256, 14, 14]    --                   True
# │    └─BasicBlock (0)                    [16, 128, 28, 28]    [16, 256, 14, 14]    --                   True
# │    │    └─Conv2d (conv1)               [16, 128, 28, 28]    [16, 256, 14, 14]    294,912              True
# │    │    └─BatchNorm2d (bn1)            [16, 256, 14, 14]    [16, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [16, 256, 14, 14]    [16, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [16, 256, 14, 14]    [16, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [16, 256, 14, 14]    [16, 256, 14, 14]    512                  True
# │    │    └─Sequential (downsample)      [16, 128, 28, 28]    [16, 256, 14, 14]    33,280               True
# │    │    └─ReLU (relu)                  [16, 256, 14, 14]    [16, 256, 14, 14]    --                   --
# │    └─BasicBlock (1)                    [16, 256, 14, 14]    [16, 256, 14, 14]    --                   True
# │    │    └─Conv2d (conv1)               [16, 256, 14, 14]    [16, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn1)            [16, 256, 14, 14]    [16, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [16, 256, 14, 14]    [16, 256, 14, 14]    --                   --
# │    │    └─Conv2d (conv2)               [16, 256, 14, 14]    [16, 256, 14, 14]    589,824              True
# │    │    └─BatchNorm2d (bn2)            [16, 256, 14, 14]    [16, 256, 14, 14]    512                  True
# │    │    └─ReLU (relu)                  [16, 256, 14, 14]    [16, 256, 14, 14]    --                   --
# ├─Sequential (layer4)                    [16, 256, 14, 14]    [16, 512, 7, 7]      --                   True
# │    └─BasicBlock (0)                    [16, 256, 14, 14]    [16, 512, 7, 7]      --                   True
# │    │    └─Conv2d (conv1)               [16, 256, 14, 14]    [16, 512, 7, 7]      1,179,648            True
# │    │    └─BatchNorm2d (bn1)            [16, 512, 7, 7]      [16, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [16, 512, 7, 7]      [16, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [16, 512, 7, 7]      [16, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn2)            [16, 512, 7, 7]      [16, 512, 7, 7]      1,024                True
# │    │    └─Sequential (downsample)      [16, 256, 14, 14]    [16, 512, 7, 7]      132,096              True
# │    │    └─ReLU (relu)                  [16, 512, 7, 7]      [16, 512, 7, 7]      --                   --
# │    └─BasicBlock (1)                    [16, 512, 7, 7]      [16, 512, 7, 7]      --                   True
# │    │    └─Conv2d (conv1)               [16, 512, 7, 7]      [16, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn1)            [16, 512, 7, 7]      [16, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [16, 512, 7, 7]      [16, 512, 7, 7]      --                   --
# │    │    └─Conv2d (conv2)               [16, 512, 7, 7]      [16, 512, 7, 7]      2,359,296            True
# │    │    └─BatchNorm2d (bn2)            [16, 512, 7, 7]      [16, 512, 7, 7]      1,024                True
# │    │    └─ReLU (relu)                  [16, 512, 7, 7]      [16, 512, 7, 7]      --                   --
# ├─AdaptiveAvgPool2d (avgpool)            [16, 512, 7, 7]      [16, 512, 1, 1]      --                   --
# ├─Linear (fc)                            [16, 512]            [16, 1000]           513,000              True
# ========================================================================================================================
# Total params: 11,689,512
# Trainable params: 11,689,512
# Non-trainable params: 0
# Total mult-adds (G): 29.03
# ========================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 635.96
# Params size (MB): 46.76
# Estimated Total Size (MB): 692.35
# ========================================================================================================================

# %% [markdown]
# ## Trying out the LSTM Model (from PyTorch Tutorial)
#
# Link: [Sequence Models and Long Short-Term Memory Networks](https://pytorch.org/tutorials/beginner/nlp/sequence_models_tutorial.html)

# %%
import torch
import torch.nn.functional as F

class LSTMTagger(torch.nn.Module):

	def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
		super(LSTMTagger, self).__init__()
		self.hidden_dim = hidden_dim

		self.word_embeddings = torch.nn.Embedding(vocab_size, embedding_dim)

		# The LSTM takes word embeddings as inputs, and outputs hidden states
		# with dimensionality hidden_dim.
		self.lstm = torch.nn.LSTM(embedding_dim * (vocab_size - 1), hidden_dim)

		# The linear layer that maps from hidden state space to tag space
		self.hidden2tag = torch.nn.Linear(hidden_dim, tagset_size)

	def forward(self, sentence):
		embeds = self.word_embeddings(sentence)
		print(embeds.shape) # batch size of 10, vocab size of 30, embedding dim of 20
		print(embeds.view(len(sentence), -1).shape)

		lstm_out, _ = self.lstm(embeds.view(len(sentence), -1))
		print("got here!")
		print(lstm_out.shape)
		print(lstm_out.view(len(sentence), -1).shape)

		tag_space = self.hidden2tag(lstm_out)
		tag_scores = F.log_softmax(tag_space, dim=1)
		return tag_scores

input_to_model = torch.randint(low=0, high=30, size=(10,30))
# print(input_to_model)
model = LSTMTagger(
	embedding_dim=20,
	hidden_dim=100,
	vocab_size=30+1,
	tagset_size=2,
)
outputs = model(input_to_model)
# Out:
# torch.Size([10, 30, 20])
# torch.Size([10, 600])
# got here!
# torch.Size([10, 100])
# torch.Size([10, 100])
